# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %%
df_apple = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv')

# %%
df_apple
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
df_apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
df_apple.Date = df_apple.Date.astype('datetime64')

# %%
df_apple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
#df_apple = df_apple.set_index(df_apple.Date)

# %%
df_apple
# Out:
#            Date   Open   High    Low  Close     Volume  Adj Close
# 0    2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1    2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2    2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3    2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4    2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...         ...    ...    ...    ...    ...        ...        ...
# 8460 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
df_apple.index.has_duplicates
# Out:
# False

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
df_apple = df_apple.sort_values('Date')

# %%
df_apple = df_apple.set_index(df_apple.Date)

# %%
df_apple
# Out:
#                  Date   Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# ...               ...    ...    ...    ...    ...        ...        ...
# 2014-07-01 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 2014-07-02 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-03 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-07 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-08 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
df_apple['BMonthEnd'] = (df_apple.index + pd.offsets.BMonthEnd(0)).day

# %%
df_apple
# Out:
#                  Date   Open   High    Low  Close     Volume  Adj Close  \
# Date
# 1980-12-12 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# ...               ...    ...    ...    ...    ...        ...        ...
# 2014-07-01 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 2014-07-02 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-03 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-07 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-08 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
#             BMonthEnd
# Date
# 1980-12-12         31
# 1980-12-15         31
# ...

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
df_apple.index.max()-df_apple.index.min()
# Out:
# Timedelta('12261 days 00:00:00')

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
len(df_apple.groupby([df_apple.Date.dt.year, df_apple.Date.dt.month]).size())
# Out:
# 404

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
import plotly.express as px

# %%
px.line(df_apple, x=df_apple.index, y='Adj Close', width=13.5, height=9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [119], in <cell line: 1>()
# ----> 1 px.line(df_apple, x=df_apple.index, y='Adj Close', width=[13.5], height=9)
#
# File ~\miniconda3\lib\site-packages\plotly\express\_chart_types.py:262, in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     214 def line(
#     215     data_frame=None,
#     216     x=None,
#    (...)
#     256     height=None,
#     257 ):
# ...

# %%
px.line(df_apple, x=df_apple.index, y='Adj Close')

# %% [markdown]
# ### BONUS: Create your own question and answer it.
